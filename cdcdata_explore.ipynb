# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Data file
cdcdata_path = "data/Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2016-2018.csv"

# Read heart disease data
cdcdata_df = pd.read_csv(cdcdata_path)

cdcdata_df
# Out:
#        Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0      2017           AK  Aleutians East          County       NVSS
# 1      2017           AK  Aleutians West          County       NVSS
# 2      2017           AK       Anchorage          County       NVSS
# 3      2017           AK          Bethel          County       NVSS
# 4      2017           AK     Bristol Bay          County       NVSS
# ...     ...          ...             ...             ...        ...
# 59089  2017           WY         Wyoming           State       NVSS
# 59090  2017           WY         Wyoming           State       NVSS
# 59091  2017           WY         Wyoming           State       NVSS
# 59092  2017           WY         Wyoming           State       NVSS
# 59093  2017           WY         Wyoming           State       NVSS
#
#                          Class                    Topic Data_Value  \
# 0      Cardiovascular Diseases  Heart Disease Mortality      172.9
# ...

# %%
cdcdata_df.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'GeographicLevel', 'DataSource',
#        'Class', 'Topic', 'Data_Value', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'TopicID', 'LocationID', 'Y_lat', 'X_lon'],
#       dtype='object')

# %%
cdcdata_df["LocationDesc"].values
# Out:
# array(['Aleutians East', 'Aleutians West', 'Anchorage', ..., 'Wyoming',
#        'Wyoming', 'Wyoming'], dtype=object)

# %%
cdcdata_df["GeographicLevel"].value_counts()
# Out:
# County    58068
# State      1008
# Nation       18
# Name: GeographicLevel, dtype: int64

# %%
cdcdata_df["GeographicLevel"].value_counts()
# Out:
# County    58068
# State      1008
# Nation       18
# Name: GeographicLevel, dtype: int64

# %%
cdcdata_clean = cdcdata_df.rename(columns={'Year': 'Year', 'LocationAbbr':'LocationAbbr', 'LocationDesc': 'LocationDesc', 'GeographicLevel':'GeographicLevel', 'DataSource':'DataSource',
       'Class': 'Class', 'Topic': 'Topic', 'Data_Value': "Mortality_Rate", 'Data_Value_Unit': "Morality_Rate_Unit", 'Data_Value_Type': 'Morality_Rate_Type',
       'Data_Value_Footnote_Symbol':'Data_Value_Footnote_Symbol' , 'Data_Value_Footnote':'Mortality_Rate_Footnote',
       'StratificationCategory1':'StratificationCategory1' , 'Stratification1': 'Gender', 'StratificationCategory2':'StratificationCategory2',
       'Stratification2': 'Race', 'TopicID': 'TopicID', 'LocationID':'LocationID', 'Y_lat':'Y_Lat', 'X_lon': "X_Lon"})

# %%
cdcdata_clean.head()
# Out:
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2017           AK  Aleutians East          County       NVSS
# 1  2017           AK  Aleutians West          County       NVSS
# 2  2017           AK       Anchorage          County       NVSS
# 3  2017           AK          Bethel          County       NVSS
# 4  2017           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic Mortality_Rate  \
# 0  Cardiovascular Diseases  Heart Disease Mortality          172.9
# 1  Cardiovascular Diseases  Heart Disease Mortality          172.2
# 2  Cardiovascular Diseases  Heart Disease Mortality          243.3
# 3  Cardiovascular Diseases  Heart Disease Mortality          337.1
# 4  Cardiovascular Diseases  Heart Disease Mortality            NaN
#
#        Morality_Rate_Unit                                 Morality_Rate_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# ...

# %%
cdcdata_clean["Mortality_Rate"].count()
# Out:
# 32550

# %%
morality_clean = cdcdata_clean.dropna(subset=['Mortality_Rate'])

# %%
morality_clean["Mortality_Rate"].count()
# Out:
# 32550
